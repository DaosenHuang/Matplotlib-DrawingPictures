# %%
import seaborn as sb
import numpy as np
import matplotlib.pyplot as plt

# %%
sb.set(style="whitegrid") # 设置图表风格，默认为darkgrid
tips = sb.load_dataset("tips") # 加载自带数据集

sb.relplot(x="total_bill",y="tip",col="time",hue="smoker",style="smoker",size="size",data=tips)
